# %% [markdown]
# # Simple Template-Based Approach

# %%
import random
import pandas as pd
import numpy as np
import csv
import spacy
sp = spacy.load('en_core_web_sm')
import nltk
from nltk.tokenize import word_tokenize
import re
nltk.download('tagsets')
from nltk.data import load
from nltk.corpus import conll2000
import pickle
# Out:
# [nltk_data] Downloading package tagsets to /Users/renny/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!

# %% [markdown]
# ## 1. Load Parameters

# %%
with open('output/tagged_tags_dictionary_withsents_film.pkl','rb') as f:
    tagged_tags_dictionary = pickle.load(f)
    
with open('output/mapped_tags_to_group_film','rb') as f:
    mapped_tags_to_group = pickle.load(f)
    
with open('output/mapped_tags_to_group_nonperson_film','rb') as f:
    mapped_tags_to_group_nonperson = pickle.load(f)

    
cleaned_list_of_tags = tagged_tags_dictionary.keys()

tags_dataframe = pd.DataFrame(tagged_tags_dictionary).T.reset_index().rename(columns={'index': 'Tags'})   

like_synonyms_basic = ["like"]
dont_like_synonyms_basic = ["don't like"]
like_synonyms=["like","love","prefer","enjoy","are into", "would watch", "like to watch","like watching", "love to watch","love watching","prefer to watch","prefer watching","enjoy watching","are interested in"]
dont_like_synonyms=["dislike","don't like","hate","don't prefer","are not into", "wouldn't watch","dislike watching","don't like to watch","don't like watching","hate to watch","hate watching","don't prefer watching","don't prefer to watch","are not interested in"]
especially_synonyms = ["especially", "particularly"]
unless_synonyms = ["unless","except if"]

# %% [markdown]
# ### Basic template adapted from the paper :
# 1. You (don't) like {tag1} movies especially if they are {tag2} -- for ((tag1,+), (tag2,++)) or ((tag1,-),(tag2,--))
# 2. You (don't) like {tag1} movies especially if they are not {tag2} -- for ((tag1,++),(tag2,+)) or ((tag1,--),(tag2,-))
# 3. You (don't) like {tag1} movies unless they are {tag2} -- for ((tag1,+),(tag2,-)) or ((tag1,-),(tag2,+))
# 4. You (don't) like {tag1} movies if they are {tag2} -- for ((tag1,N),(tag2,+)) or ((tag1,N),(tag2,-))
#
#
# ### Function get_summary
# This function is to generate phrase based on above basic template, it will take tuple of tag1 and tag2, where each contain a pair of text and the sign (+,++,-, etc.), and return the phrase.
#
# In this function, it will generate sentence 1 and sentence 2 by calling function get_first_sentence, and get_second_sentence. The generated sentence 1 and 2 will have similar meaning with the sentence it replaced, it is just can have different pattern. The tag text will not be changed.
#
# Example from the first basic template:
#
# <img src="screenshot.png" width="400" height="200" >
#
#
# ### Function get_first_sentence
# It is to generate sentence 1 part, by picking random pattern which is basically different ways of saying the basic form.
# In each sentence pattern, it will also pick randomly different words for expressing like or don't like.
# The pattern for the sentence is manually picked (there are 3 patterns), and the different expresison of like/don't like is also manually picked.
#
# ### Function get_second_sentence
# It is to generate sentence 2 part, with the same way of get_first_sentence function.

# %%
### Basic_2 templates


def get_first_sentence(tag,sentiment = 1):
    group = tagged_tags_dictionary[tag]['POS_Tags_Group']
    entity = tagged_tags_dictionary[tag]['Entity']  
    person_type = tagged_tags_dictionary[tag]['Person_Type']
    end_with_movie = tagged_tags_dictionary[tag]['End_with_movie']
    start_pos = tagged_tags_dictionary[tag]['Start_POS']
    end_pos = tagged_tags_dictionary[tag]['End_POS']
    genre = tagged_tags_dictionary[tag]['genre']
    
    #if end with movie/movies/film/films
    if end_with_movie == True:
         statement_patterns = ["You {} [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag)]#, #Basic pattern
            
    elif entity == 'GPE':
        statement_patterns = ["You {} movies about [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag),
                             "You {} movies from [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag)]
    elif genre==True:
        statement_patterns = ["You {} [{}] movies".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag),
                             "You {} movies with [{}] {}".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag,random.choice(['genre','content'])),
                             "You {} movies full of [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag)]
        
    
    #elif tag.startswith('oscar'): ## Since oscar is a famous award, make own rule for it
    #    statement_patterns = ["You {} '{}' movies".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag)]
    
    elif ((group == 'noun') | (group == 'numeral')) & (not tag.startswith("oscar")):
        if entity == 'PERSON':
            if person_type == 'actor':
                  statement_patterns = ["You {} movies starred by [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag), #Basic pattern
                                       "You {} movies starring [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag),   
                                        "You {} movies played by [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag),
                                        "[{}] movies is {}for you".format(tag.capitalize(), "" if sentiment==1 else "not ")]
            elif (person_type == 'director'):
                statement_patterns = ["You {} movies directed by [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag), #Basic pattern
                          "[{}] movies is {}for you".format(tag.capitalize(), "" if sentiment==1 else "not ")]
            else:
                statement_patterns = ["You {} movies about [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag)]
    
        elif ((start_pos.startswith('JJ')) | (start_pos=='DT')) & (end_pos=='VBG'):
            statement_patterns = ["You {} movies with [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag)]
    
        else:
            statement_patterns = ["You {} movies about [{}]".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag)]
    

    else : #adjective & other
        statement_patterns = ["You {} [{}] movies".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag), #Basic pattern
                              "[{}] movies is {}for you".format(tag.capitalize(), "" if sentiment==1 else "not ")]
                              #  "You {} movies filled with '{}'".format(random.choice(like_synonyms) if sentiment == 1 else random.choice(dont_like_synonyms),tag)]

    return(random.choice(statement_patterns))

def get_second_sentence(tag,sentiment = 1):
    group = tagged_tags_dictionary[tag]['POS_Tags_Group']
    entity = tagged_tags_dictionary[tag]['Entity']
    person_type = tagged_tags_dictionary[tag]['Person_Type']
    end_with_movie = tagged_tags_dictionary[tag]['End_with_movie']
    start_pos = tagged_tags_dictionary[tag]['Start_POS']
    end_pos = tagged_tags_dictionary[tag]['End_POS']
    genre = tagged_tags_dictionary[tag]['genre']
    
    
    if end_with_movie == True:
        statement_patterns = ["they are {}[{}]".format("" if sentiment==1 else "not ",tag)]#,#Basic pattern for second sentence
    
    elif entity == 'GPE':
        statement_patterns = ["they are {}about [{}]".format("" if sentiment==1 else "not ",tag),
                             "they are {}from [{}]".format("" if sentiment==1 else "not ",tag)]
    
    elif tag.startswith('oscar'): ## Since oscar is a famous award, make own rule for it
        statement_patterns = ["they are {}[{}] movies".format("" if sentiment==1 else "not ",tag)]
  
    elif genre == True:
        statement_patterns = ["they are {}full of [{}]".format("" if sentiment==1 else "not ",tag),
                             "they {} [{}]".format("contain" if sentiment==1 else "don't contain",tag),
                             "they are {}[{}]".format("" if sentiment==1 else "not ",tag)]
    
    elif (group == 'noun') | (group == 'numeral'):
        if entity == 'PERSON':
            if person_type == 'actor':
                  statement_patterns = ["they are {}starred by [{}]".format("" if sentiment==1 else "not ",tag), #Basic pattern
                          "they are {}starring [{}]".format("" if sentiment==1 else "not ",tag),
                          "they are {}played by [{}]".format("" if sentiment==1 else "not ",tag)]
            elif (person_type == 'director'):
                statement_patterns = ["they are {}directed by [{}]".format("" if sentiment==1 else "not ",tag),
                                      "they are {}movies by [{}]".format("" if sentiment==1 else "not ",tag)]
            else:
                statement_patterns = ["they are {}about [{}]".format("" if sentiment==1 else "not ",tag),
                                 "they are {}[{}] movies".format("" if sentiment==1 else "not ",tag)]
        
        elif ((start_pos.startswith('JJ')) | (start_pos=='DT')) & (end_pos=='VBG'):
            statement_patterns = ["they are {}with [{}]".format("" if sentiment==1 else "not ",tag)]
                
        else:
            statement_patterns = ["they are {}about [{}]".format("" if sentiment==1 else "not ",tag)]
    

    else : #adjectives and others, also if end_with_movie == True
    # Below are manually set pattern for first sentence with positive or negative sentiment which can be randomly chosen
        statement_patterns = ["they are {}[{}]".format("" if sentiment==1 else "not ",tag)]#,#Basic pattern for second sentence
                         # $"they are {}full of '{}'".format("" if sentiment==1 else "not ", tag),
                        #"they {} high '{}' content".format("have" if sentiment==1 else "don't have",tag)]
   
    
    
    return(random.choice(statement_patterns))

def get_summary_basic_2(tag1,tag2):
    " Function to generate template_based summary/phrase, using basic template as above explanation in markdown"
    
    if len(tag1[1]) ==1:
        
        if len(tag2[1])==2:
            #1st template (+,++) or (-,--)
            sentiment_1 = 1 if tag1[1]=='+' else 0
            return "{}, {} if {}.".format(get_first_sentence(tag1[0],sentiment_1),random.choice(especially_synonyms),get_second_sentence(tag2[0])) #especially
            
        else:
            #4th template (N,+) or (N,-)
            if tag1[1] == 'N':
                sentiment_1 = 1 if tag2[1]=='+' else 0
                return "{} if {}.".format(get_first_sentence(tag1[0],sentiment_1),get_second_sentence(tag2[0]))
    
            #3rd template (+,-) or (-,+)    
            else:
                    sentiment_1 = 1 if tag1[1]=='+' else 0
                    return "{}, {} {}.".format(get_first_sentence(tag1[0],sentiment_1),random.choice(unless_synonyms),get_second_sentence(tag2[0])) #unless
    
    #2nd template (++,+) or (--,-)
    else:
        sentiment_1 = 1 if tag1[1]=='++' else 0
        return "{}, {} if {}.".format(get_first_sentence(tag1[0],sentiment_1),random.choice(especially_synonyms),get_second_sentence(tag2[0],0))#especially

# %% [markdown]
# ## 1.3 Get N preference statements
# To generate n number of preference statement, with random tags and random preferences level

# %%
def generate_preference_statements(num_statements, tags, template_type=1): 
    '''
    param num_statements : number of statements to be generated
    param tags : list of tags. From this list, the tags for each statement will be randomly choosen
    '''
    list_preference_statements = []
    list_preference = []
    list_tags = []
    list_postags = []

    for i in range(num_statements):
        pair_tags = random.sample(tags,k=2)
        list_postags.append([tags_dataframe[tags_dataframe['Tags']==pair_tags[0]]['POS_Tags'].values[0],tags_dataframe[tags_dataframe['Tags']==pair_tags[1]]['POS_Tags'].values[0]])
        pair_preferences = random.choice(list_of_preference)
        if template_type == 1:
            pref_statement = get_summary_basic_1((pair_tags[0],pair_preferences[0]),(pair_tags[1],pair_preferences[1]))
        elif template_type == 2:
            pref_statement = get_summary_basic_2((pair_tags[0],pair_preferences[0]),(pair_tags[1],pair_preferences[1]))
        print (pref_statement)
        list_preference_statements.append(pref_statement)
        list_preference.append(pair_preferences)
        list_tags.append(pair_tags)
    return list_preference_statements, list_preference,list_tags, list_postags

# %% [markdown]
# ## 1.4 Other function(s)

# %%
def save_to_file(title,list_preference_statements, list_preference,list_tags, list_postags):   
    '''
    Saving the generated statements into excel file
    '''
    # Write the generated sentences in a csv file for review
    list_tags = np.array(list_tags)
    list_preference = np.array(list_preference)
    list_postags = np.array(list_postags)
    
    pd.DataFrame({'Preference_statement': list_preference_statements,
                  'tag1': list_tags[0:,0],
                  'pos-tag1' : list_postags[0:,0],
                  'pref1': list_preference[0:,0],
                  'tag2': list_tags[0:,1],
                  'pos-tag2' : list_postags[0:,1],
                  'pref2': list_preference[0:,1]
    }).to_excel("output/"+title)

# %% [markdown]
# # 3. Generate Preference statements

# %%
list_of_preference = [('+','++'),('-','--'),('++','+'),('--','-'),('+','-'),('-','+'),('N','+'),('N','-')]

# %%
# Generate preference statements with all filtered tags
list_preference_statements, list_preference, list_tags, list_postags = generate_preference_statements(100,cleaned_list_of_tags,template_type=2)
save_to_file('preference_statement_all_210320_w_sent_film_basic1.xlsx',list_preference_statements, list_preference,list_tags,list_postags)
# Out:
# You prefer [jamie foxx] movies especially if they are not [jonathan pryce].
# You like [unsympathetic characters] movies unless they are [free running].
# You don't prefer [americans abroad] movies unless they are [nerd].
# You hate [midlife crisis] movies especially if they are [camera].
# You like [life in general] movies especially if they are not [charles laughton].
# You dislike [edward furlong] movies especially if they are [unintelligent].
# You dislike [yul brynner] movies especially if they are [vanity].
# You prefer [sherlock holmes] movies especially if they are not [overly simplistic].
# You love [oscar (best picture)] movies unless they are [kathy bates].
# You enjoy [psychoanalysis] movies especially if they are [apocalyptic].
# You hate [silly] movies if they are [original].
# You are not into [ancient civilization] movies especially if they are not [lots of blood].
# You love [soccer] movies unless they are [relaxing].
# You prefer [living with disability] movies unless they are [maria bello].
# You hate [no tension] movies unless they are [subgenre:kaiju].
# You don't like [julie taymor] movies especially if they are not [arranged marriages].
# You love [argentina] movies especially if they are [post-modern].
# You are into [very funny!] movies unless they are [classic].
# You hate [billy west] movies unless they are [vietnam war based movie].
# You are into [delusional] movies especially if they are [fiction].
# You dislike [krzysztof kieslowski] movies if they are [israel].
# You are not into [political correctness] movies especially if they are [magicians].
# You prefer [dennis quaid] movies if they are [flight].
# You dislike [silly but good] movies if they are [family issues].
# You are not into [resistance] movies especially if they are [jamie foxx].
# You enjoy [twists] movies if they are [cultural authenticity].
# You like [depp and burton] movies unless they are [dana carvey].
# You are not into [black humor] movies especially if they are [police corruption].
# You don't like [so bad it's good] movies especially if they are not [decline of civilization].
# You prefer [stylistic] movies especially if they are not [switzerland].
# You dislike [natives] movies especially if they are [experiments gone awry].
# You dislike [betamax] movies especially if they are not [great cinematography].
# You dislike [missionary] movies if they are [annoying].
# You enjoy [funniest movies] movies if they are [ki-duk kim].
# You prefer [alexander payne] movies especially if they are [too simple plot].
# You love [whoopi goldberg] movies especially if they are [candice bergen].
# You dislike [personal] movies unless they are [david yates].
# You hate [merlin] movies especially if they are not [loud].
# You enjoy [extremely gory] movies especially if they are [awful movie].
# You are not into [subtitles] movies especially if they are not [tear-jerker].
# You dislike [teacher student relationship] movies especially if they are not [universal monsters].
# You hate [american football] movies if they are [drugs & music].
# You love [addiction] movies especially if they are [doris day].
# You don't prefer [golden raspberry (worst actor)] movies unless they are [great cinematography].
# You are into [dustin hoffman] movies if they are [career].
# You are not into [charlize theron] movies unless they are [animal].
# You don't like [oded fehr] movies if they are [relationships].
# You enjoy [anamorphic blow-up] movies especially if they are not [actors].
# You like [oscar (best actor)] movies unless they are [treason].
# You prefer [suburban dysfunction] movies if they are [war hero].
# You dislike [good plot] movies unless they are [weddings].
# You are not into [luc besson] movies if they are [dwarf].
# You are not into [office] movies unless they are [dickens].
# You are into [melodrama] movies especially if they are [open ending].
# You like [universal monsters] movies unless they are [dostoyevsky].
# You enjoy [astaire and rogers] movies especially if they are [eugene levy].
# You prefer [monsters] movies especially if they are not [tomboy].
# You dislike [interviews] movies if they are [ku klux klan].
# You enjoy [weak plot] movies if they are [future].
# You enjoy [peter greenaway] movies especially if they are [silent film].
# You love [hugh laurie] movies especially if they are [controversial].
# You are into [angela bassett] movies especially if they are not [penãƒâ©lope cruz].
# You are not into [isla fisher] movies if they are [grotesque].
# You like [lacey chabert] movies especially if they are [unrealistic].
# You are not into [abuse] movies if they are [romcom].
# You prefer [desperation] movies unless they are [poignant].
# You love [joseph cross] movies especially if they are [book was better].
# You enjoy [violent] movies especially if they are [gene hackman].
# You enjoy [richard attenborough] movies especially if they are not [cat killing].
# You are not into [gwyneth paltrow] movies especially if they are not [aamir khan].
# You hate [great lines] movies if they are [coal miners].
# You dislike [wall street] movies especially if they are not [videogame like].
# You dislike [snl] movies especially if they are not [danny kaye].
# You dislike [media] movies if they are [rod steiger].
# You hate [james mason] movies especially if they are not [rise and fall stories].
# You don't prefer [thin plot] movies especially if they are not [child murder].
# You are into [fantasy] movies especially if they are [puerto rico].
# You don't like [mary-louise parker] movies especially if they are [irritating].
# You dislike [jeffrey dean morgan] movies unless they are [makes no sense].
# You don't prefer [ghibli] movies unless they are [gene hackman].
# You dislike [actors] movies especially if they are not [journey].
# You are into [marijuana] movies especially if they are not [caper movie].
# You hate [indiana jones] movies if they are [identity crisis].
# You don't prefer [oscar (best foreign language film)] movies if they are [rock opera].
# You dislike [billy crudup] movies if they are [christopher plummer].
# You love [less than 300 ratings] movies especially if they are not [lesbian].
# You are not into [witchcraft] movies especially if they are not [sadistic].
# You are into [uma thruman] movies especially if they are [josh peck].
# You love [michael j. fox] movies unless they are [b movie].
# You enjoy [new mexico] movies if they are [adrenaline junkie].
# You love [christian bale] movies unless they are [rebels].
# You like [egomaniacs] movies especially if they are not [missionary].
# You don't prefer [stallone] movies especially if they are [danny elfman].
# You don't prefer [john ford] movies unless they are [ryan gosling].
# You enjoy [misanthropic] movies unless they are [water].
# You prefer [olivia wilde] movies especially if they are not [ambition].
# You dislike [end of the world] movies unless they are [scientist].
# You are not into [rehash sequel] movies if they are [transphobia].
# You love [hideaki anno] movies especially if they are [grocery store].
# You are not into [freedom] movies unless they are [being a kid again].

# %%
# Generate preference statements with tags tagged as adjective
adjectives_tags = mapped_tags_to_group['adjective']
list_preference_statements, list_preference, list_tags, list_postags = generate_preference_statements(100,adjectives_tags, template_type=2)
save_to_file('preference_statement_adjective_210320_basic1.xlsx',list_preference_statements, list_preference,list_tags,list_postags)
# Out:
# You love [ninja] movies if they are [self-sacrifice].
# You prefer [retro-futuristic] movies unless they are [off-beat].
# You don't like [anti-hero] movies especially if they are [motown].
# You are not into [musician] movies especially if they are not [wonderful].
# You are into [delorean] movies if they are [superficial].
# You are not into [twisted] movies especially if they are [pows].
# You don't like [nerd] movies especially if they are [meditative].
# You don't like [raw] movies especially if they are [funny!].
# You like [spaceships] movies unless they are [panic].
# You are not into [quiet] movies especially if they are [schizophrenic].
# You hate [pagan] movies especially if they are [subversive].
# You like [self-indulgent] movies unless they are [magical].
# You prefer [owls] movies especially if they are [immoral].
# You enjoy [autumnal] movies especially if they are not [rated-r].
# You like [slow-paced] movies if they are [weak].
# You enjoy [frivolous] movies unless they are [noir].
# You don't prefer [lovecraftian] movies especially if they are not [ironic].
# You love [apocalyptic] movies if they are [scrabble].
# You like [dead] movies unless they are [psychopaths].
# You love [toys] movies unless they are [queen].
# You are into [over-the-top] movies especially if they are not [epidemic].
# You dislike [over-the-top] movies especially if they are not [painful].
# You prefer [greek] movies especially if they are not [trippy].
# You enjoy [stunning] movies especially if they are [unfunny].
# You are into [russian] movies especially if they are not [dull].
# You are not into [teens] movies especially if they are not [undead].
# You love [too short] movies especially if they are [complex].
# You dislike [lengthy] movies if they are [dream-like].
# You don't prefer [ninjas] movies unless they are [highly quotable].
# You enjoy [german] movies especially if they are [nazi].
# You don't prefer [intelligent] movies unless they are [spaceships].
# You don't like [medical] movies unless they are [nice].
# You prefer [liberal] movies especially if they are not [catholic].
# You dislike [magician] movies especially if they are [cathartic].
# You dislike [typical] movies unless they are [tarkovsky].
# You are into [existential] movies unless they are [tasteful].
# You dislike [unimaginative] movies especially if they are [amazing!].
# You enjoy [not funny] movies unless they are [cerebral].
# You don't like [mean-spirited] movies especially if they are not [low-brow].
# You like [confrontational] movies especially if they are [animated].
# You are not into [landscapes] movies especially if they are [tasteful].
# You don't like [geek] movies if they are [classical].
# You enjoy [dream-like] movies unless they are [medical].
# You don't like [fantastic] movies especially if they are [story-in-a-story].
# You are into [idiotic] movies especially if they are not [ukraine].
# You are not into [futuristic] movies especially if they are [gritty].
# You are into [over-the-top] movies unless they are [immoral].
# You are into [cheap] movies unless they are [gross].
# You enjoy [quirky] movies especially if they are [cameo-fest].
# You hate [utopia] movies especially if they are [bible].
# You prefer [popcorn] movies if they are [owned].
# You are into [retro-futuristic] movies if they are [schizophrenic].
# You hate [self-mocking] movies especially if they are [influential].
# You are not into [phylosophycal] movies especially if they are not [legal].
# You don't prefer [trippy] movies if they are [forceful].
# You prefer [childish] movies especially if they are not [cryptic].
# You don't prefer [chinese] movies especially if they are not [unengaging].
# You don't prefer [trivial] movies especially if they are not [cameo-fest].
# You hate [missionary] movies if they are [eccentric].
# You enjoy [nasa] movies especially if they are not [surreal].
# You hate [austere] movies especially if they are not [not very funny].
# You hate [sad] movies if they are [stereotypes].
# You don't prefer [courtesan] movies especially if they are not [black].
# You dislike [italian] movies unless they are [bitter].
# You dislike [violently stupid] movies especially if they are [eye-opening].
# You enjoy [very funny] movies especially if they are [unfunny].
# You are into [fanciful] movies unless they are [decent].
# You dislike [over-the-top] movies especially if they are [xenophobia].
# You are into [visceral] movies if they are [teens].
# You are not into [quite romantic] movies unless they are [hillarious].
# You enjoy [not very funny] movies unless they are [kiss].
# You like [violent] movies unless they are [scary].
# You dislike [suspenseful] movies especially if they are [creative].
# You don't like [unbearable] movies if they are [intense].
# You enjoy [freaks] movies if they are [biased].
# You dislike [fairy-tale] movies unless they are [colourful].
# You enjoy [rushed] movies unless they are [believable].
# You love [uneven] movies especially if they are not [threesome].
# You enjoy [over-hyped] movies especially if they are [funny].
# You enjoy [formulaic] movies especially if they are [comic].
# You don't prefer [lavish] movies especially if they are not [simple].
# You don't prefer [onesided] movies especially if they are not [multicultural].
# You dislike [current] movies unless they are [over-hyped].
# You dislike [black-and-white] movies especially if they are [thought-provoking].
# You dislike [realistic] movies especially if they are not [extremely gory].
# You don't like [mockumentary] movies unless they are [multicultural].
# You prefer [sentimental] movies especially if they are not [comic].
# You prefer [anti-war] movies unless they are [airships].
# You are not into [nice] movies especially if they are not [trippy].
# You dislike [aliens] movies unless they are [scams].
# You dislike [nazi] movies especially if they are [chaotic].
# You dislike [inaccurate] movies unless they are [musician].
# You dislike [fish] movies if they are [unfaithfulness].
# You like [stylistic] movies especially if they are [surprising].
# You enjoy [funeral] movies if they are [extremely gory].
# You love [catholic] movies if they are [low-brow].
# You are not into [very funny] movies if they are [teen].
# You dislike [subversive] movies unless they are [iconic].
# You are not into [musician] movies especially if they are not [unusual].
# You like [witty!] movies especially if they are [supernatural].

# %%
# Generate preference statements which tags tagged as other than nouns
non_noun_tags = []
for item in mapped_tags_to_group_nonperson:
    if item !='noun':
        non_noun_tags = non_noun_tags + mapped_tags_to_group_nonperson[item]
        
list_preference_statements, list_preference, list_tags,list_postags = generate_preference_statements(100,non_noun_tags,template_type=2)
save_to_file('preference_statement_non_adjective_nonPerson_230320_basic1.xlsx',list_preference_statements, list_preference,list_tags,list_postags)
# Out:
# You enjoy [movie to see] movies especially if they are not [photographer].
# You dislike [amazon] movies especially if they are [mormon].
# You hate [chaos] movies especially if they are [boring beginning].
# You don't like [globalisation] movies unless they are [all-star cast].
# You don't like [eco] movies unless they are [race].
# You are not into [not enough action] movies especially if they are [french film].
# You enjoy [medicine] movies unless they are [singing].
# You prefer [misunderstanding] movies if they are [rome].
# You dislike [prom] movies especially if they are not [monsters].
# You don't prefer [farming] movies unless they are [awkward romance].
# You dislike [geeky] movies especially if they are [writing process].
# You are into [metaphysics] movies especially if they are not [h.p. lovecraft].
# You hate [lack of story] movies especially if they are not [zizek].
# You don't like [tear-jerker] movies especially if they are [tension].
# You dislike [great dialouge] movies especially if they are not [leos carax].
# You don't prefer [inconsistent] movies especially if they are not [acting and story].
# You love [christmas] movies if they are [aristocracy].
# You don't like [bbc films] movies unless they are [honesty].
# You like [almodovar] movies especially if they are not [humor].
# You love [complex relationships] movies unless they are [cliche ending].
# You like [cured by love/hope] movies unless they are [no happy end].
# You are into [scenery] movies unless they are [hostage].
# You love [spain] movies if they are [singing].
# You don't prefer [male gaze] movies unless they are [menacing].
# You dislike [fraud] movies unless they are [religious zealotry].
# You like [writing process] movies especially if they are not [ethnic conflict].
# You dislike [wolverine] movies unless they are [extremely slow build].
# You don't like [watch the credits] movies if they are [personal demons].
# You prefer [ugly] movies unless they are [heroic mission].
# You are not into [bromantic comedy] movies unless they are [good acting].
# You dislike [mirrors] movies especially if they are [superpowers].
# You don't like [biting] movies if they are [heartwarming].
# You don't prefer [alcohol] movies unless they are [cute!].
# You are into [dc comics] movies especially if they are [catholicism].
# You don't prefer [the plot] movies unless they are [setting:la].
# You enjoy [sufficiently explodey to be good] movies especially if they are [shaky camera].
# You dislike [happiness] movies especially if they are not [terrible plot].
# You enjoy [technicolor] movies if they are [frustrating to watch].
# You enjoy [rave] movies especially if they are not [con artist].
# You hate [math] movies especially if they are not [industrial progress].
# You enjoy [assassination] movies especially if they are [tense].
# You dislike [golf] movies unless they are [ayn rand].
# You are into [mental illness] movies especially if they are [videotape].
# You enjoy [b movie] movies if they are [the end of the solitude].
# You dislike [creepy singing] movies especially if they are not [frightening].
# You are not into [few action scenes] movies if they are [hallucinatory].
# You dislike [weird ending] movies especially if they are [unsatisfying ending].
# You dislike [stupid characters] movies if they are [prime minister].
# You love [teenage angst] movies unless they are [minimalist].
# You don't prefer [fashion] movies unless they are [flawed characters].
# You prefer [public relations] movies especially if they are [bryce dallas howard].
# You prefer [wales] movies especially if they are not [brief encounters].
# You are not into [road movie] movies especially if they are [different perspectives].
# You are into [snake plissken] movies especially if they are [cliffhanger].
# You dislike [hacker] movies unless they are [plot holes].
# You love [newspaper theme] movies especially if they are [timur bekmambetov].
# You don't prefer [speed] movies unless they are [moral dilemma].
# You dislike [adapted from:game] movies especially if they are [subway].
# You like [wrongly accused] movies especially if they are not [hollywoodization].
# You like [dream sequence] movies especially if they are [funny when your 10. less funny when your not.].
# You love [polish movie] movies unless they are [abandonment].
# You love [garbage] movies especially if they are not [amazon].
# You prefer [animals] movies especially if they are [obsessive compulsive disorder].
# You dislike [shannen doherty] movies especially if they are [illusions].
# You don't prefer [annoying] movies unless they are [villain nonexistent or not needed for good story].
# You enjoy [discrimination] movies especially if they are not [mst3k].
# You enjoy [harvard] movies especially if they are not [poetry].
# You prefer [men in drag] movies especially if they are [emo].
# You love [carjacking] movies unless they are [drunkenness].
# You love [ai] movies unless they are [breasts].
# You are not into [tv] movies if they are [realistic relationships].
# You don't like [stop motion] movies unless they are [puzzle solving].
# You don't like [dumb ending] movies especially if they are not [great screenplay].
# You like [don't remember] movies if they are [in netflix queue].
# You love [bad dub] movies especially if they are not [pedophile].
# You love [cliched plot] movies especially if they are not [dark fantasy].
# You like [based on a poem] movies especially if they are not [god].
# You hate [authenticity] movies especially if they are [eugene hutz].
# You prefer [very little dialogue] movies if they are [domestic violence].
# You are not into [golden globe winner] movies if they are [good ending].
# You love [creepy kid] movies especially if they are [immortality].
# You are not into [soldiers] movies especially if they are not [life changing].
# You are into [dictatorship] movies especially if they are not [amazing fight choreography].
# You dislike [carjacking] movies especially if they are not [buddhist].
# You love [guillaume canet] movies if they are [devil worship].
# You dislike [chess] movies especially if they are [boarding school].
# You love [fame] movies especially if they are not [repression].
# You like [police] movies unless they are [shaky camera].
# You love [amazing fight choreography] movies especially if they are not [mystery].
# You are not into [marvel cinematic universe] movies especially if they are [cowboys].
# You hate [atonement] movies if they are [bad soundtrack].
# You don't prefer [sweet and romantic] movies especially if they are [conspiracy].
# You like [planes] movies especially if they are [gunfights].
# You prefer [period] movies if they are [breakthroughs].
# You dislike [lovecraft] movies especially if they are [competitive sport].
# You enjoy [mozart] movies especially if they are [experiment].
# You are into [shane meadows] movies especially if they are not [kids and family].
# You are not into [hacking] movies especially if they are not [brent spiner].
# You don't like [bangkok] movies especially if they are not [lies].
# You don't like [sherlock holmes] movies especially if they are not [shootout].

# %%
# Generate preference statements which tags tagged as other noun but not person entity
list_preference_statements, list_preference, list_tags,list_postags = generate_preference_statements(100,mapped_tags_to_group_nonperson['noun'], template_type=2)
save_to_file('preference_statement_non_person_noun_190320_b2.xlsx',list_preference_statements, list_preference,list_tags,list_postags)
# Out:
# You dislike movies about 'martial arts' if they are about 'fast food'.
# You dislike movies about 'wealth' if they are about 'artist mind'.
# You prefer movies about 'worth watching' especially if they are not about 'no chemistry'
# You dislike movies about 'greed' unless they are about 'russian revolution'.
# You are not into movies about 'writing' unless they are about 'russia'.
# You don't like movies about 'mortality' if they are about 'good soundtrack'.
# You enjoy movies about 'movie business' especially if they are about 'complex morality'.
# You don't like movies about 'world war ii' if they are about 'knights'.
# You dislike movies about 'hayley atwell' especially if they are about 'german perspective'.
# You hate movies about 'metaphysics' especially if they are about 'dvd'.
# You dislike movies about 'dialogue driven' unless they are about 'figure skating'.
# You like movies about 'escapism' especially if they are about 'opposites attract'.
# You dislike movies about 'soviet union' if they are about 'american civil war'.
# You don't like movies about 'felicia day' if they are about 'mick jagger'.
# You enjoy movies about 'singing' especially if they are not about 'camp'
# You don't prefer movies about 'topic:aids/hiv' unless they are about 'gay character'.
# You hate movies about 'identity' especially if they are about 'visuals'.
# You like movies about 'great visuals' especially if they are not about 'hammer film productions'
# You like movies about 'denmark' especially if they are about 'high school violence'.
# You enjoy movies about 'juvenile deliquent' especially if they are not about 'erotic tension'
# You prefer movies about 'handheld cameras' if they are about 'tearjerker'.
# You like movies about 'cheating' especially if they are about 'missing persons'.
# You like movies about 'underdeveloped characters' especially if they are about 'dream'.
# You enjoy movies about 'global warming' especially if they are about 'wilderness'.
# You don't like movies about 'pregnancy' if they are about 'church'.
# You dislike movies about 'crude' especially if they are not about 'great characters'
# You dislike movies about 'psychic character' if they are about 'political correctness'.
# You are into movies about 'premise' especially if they are not about 'no depth'
# You like movies about 'vanity' especially if they are not about 'bad direction'
# You don't prefer movies about 'religious oppression' if they are about 'southern theme'.
# You enjoy movies about 'writing process' especially if they are about 'redemption'.
# You love movies about 'sanity' if they are about 'mick jagger'.
# You don't prefer movies about 'catchy score' especially if they are about 'captain america'.
# You are not into movies about 'gorilla' if they are about 'beautiful animation'.
# You are into movies about 'ridiculous dialogue' especially if they are about 'adoption'.
# You love movies about 'fear' especially if they are not about 'bland characters'
# You love movies about 'jungle' unless they are about 'secrets'.
# You dislike movies about 'communism' especially if they are not about 'predictable movie'
# You enjoy movies about 'environment' especially if they are not about 'shocking ending'
# You enjoy movies about 'big brother' especially if they are about 'minions'.
# You prefer movies about 'loner' unless they are about 'torture'.
# You are into movies about 'buenos aires' especially if they are not about 'no dialogue'
# You like movies about 'christmas' especially if they are about 'fatherhood'.
# You enjoy movies about 'identity' unless they are about 'energy'.
# You dislike movies about 'amorality' unless they are about 'beach'.
# You love movies about 'pop culture' unless they are about 'magic realism'.
# You love movies about 'legacy' unless they are about 'salt lake city'.
# You are not into movies about 'weak plot' especially if they are about 'stalker'.
# You love movies about 'snuff' especially if they are not about 'hollywood'
# You like movies about 'paul w.s. anderson' if they are about 'morricone score'.
# You like movies about 'dentist' especially if they are not about 'kaiju'
# You dislike movies about 'tarantino' especially if they are not about 'cards'
# You prefer movies about 'russian mafia' especially if they are not about 'zero gravity'
# You don't like movies about 'vanity' unless they are about 'amateur film making'.
# You are not into movies about 'superb acting' especially if they are not about 'satire'
# You like movies about 'small-town life' unless they are about 'comic books'.
# You like movies about 'crying' especially if they are about 'punk'.
# You enjoy movies about 'apartment' especially if they are about 'too simple plot'.
# You don't prefer movies about 'corporate america' if they are about 'premise'.
# You like movies about 'tippi hedren' especially if they are not about 'high society'
# You dislike movies about 'meh' unless they are about 'emily mortimer'.
# You dislike movies about 'fun' if they are about 'insanity'.
# You dislike movies about 'good idea' especially if they are not about 'animal abuse'
# You enjoy movies about 'cruelty' especially if they are not about 'love triangle'
# You dislike movies about 'dog' especially if they are about 'wintry'.
# You love movies about 'no chemistry' especially if they are not about 'time loop'
# You prefer movies about 'patton oswalt' if they are about 'hackers'.
# You love movies about 'world record' especially if they are not about 'great dialouge'
# You dislike movies about 'virtual reality' especially if they are about 'director'.
# You don't like movies about 'animals talking' if they are about 'lacks substance'.
# You dislike movies about 'mind bending' unless they are about 'feminism'.
# You enjoy movies about 'whodunnit' if they are about 'absent fathers'.
# You don't prefer movies about 'humiliation' if they are about 'character drama'.
# You like movies about 'unnecessary remake' especially if they are about 'creative plot'.
# You prefer movies about 'social control' especially if they are about 'entirely dialogue'.
# You are not into movies about 'cultural references' especially if they are about 'mos def'.
# You dislike movies about 'legacy' especially if they are about 'pixar animation'.
# You love movies about 'great dialogue' unless they are about 'good remake'.
# You like movies about 'dehumanization' unless they are about 'great lines'.
# You don't prefer movies about 'gay romance' especially if they are not about 'bookshop'
# You prefer movies about 'tã©a leoni' especially if they are not about 'great soundtrack'
# You prefer movies about 'good cinematography' unless they are about 'beauty'.
# You like movies about 'indoctrination' especially if they are about 'summer camp'.
# You love movies about 'biting' if they are about 'telekinesis'.
# You prefer movies about 'emotion!' especially if they are not about 'miyazaki'
# You enjoy movies about 'beautiful scenery' unless they are about 'good dialogue'.
# You are not into movies about 'jensen ackles' if they are about 'engineers'.
# You hate movies about 'game' unless they are about 'evil government'.
# You prefer movies about 'judaism' especially if they are about 'not enough action'.
# You prefer movies about 'good versus evil' unless they are about 'shark'.
# You hate movies about 'teenagers' unless they are about 'inane'.
# You prefer movies about 'plotless' especially if they are about 'space opera'.
# You prefer movies about 'prejudice' especially if they are not about 'space opera'
# You love movies about 'my favourite' if they are about 'sherlock holmes'.
# You are not into movies about 'gypsy' if they are about 'ei muista'.
# You dislike movies about 'disaster' especially if they are not about 'gnosticism'
# You prefer movies about 'immature' especially if they are not about 'alternate reality'
# You dislike movies about 'homoerotic subtext' unless they are about 'space opera'.
# You don't prefer movies about 'german expressionism' especially if they are not about 'whodunit'
# You prefer movies about 'artist mind' if they are about 'animated masterpiece'.
